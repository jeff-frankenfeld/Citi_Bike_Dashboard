# %% [markdown]
# # Table of Contents

# %% [markdown]
# ## 01. Import Libraries and Data
#         Joining Description
# ## 02. Get weather data using NOAA'a API
# ## 03. Merging `df_temp` to `df`
#         Data cleaning of the missing values
# ## 04. Exporting `df_merged` as a CSV file

# %% [markdown]
# ### 01. Import Libraries and Data

# %%
# Data Manipulation
import pandas as pd  # Used for handling and analyzing structured data (DataFrames)
import numpy as np  # Provides numerical computing capabilities (arrays, statistics)

# System Operations
import os  # Enables interaction with the operating system (file paths, directories)

# API Requests & JSON Handling
import requests  # Allows making HTTP requests (used for fetching data from APIs)
import json  # Handles JSON data parsing and conversion

# Date & Time Management
from datetime import datetime  # Used for working with timestamps and date conversions

# %%
# Create a list with all files in the '02 Data' folder using a list comprehension

# Define the absolute folder path (Use 'r' to prevent escape sequence issues)
folderpath = r"C:\Users\HP\Citi_Bike_Dashboard\02 Data\Original Data"

# Generate a list of full file paths in the folder
filepaths = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
filepaths
# Out:
# ['C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202201-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202201-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202202-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202202-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202203-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202203-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202204-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202204-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202204-citibike-tripdata_3.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202205-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202205-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202205-citibike-tripdata_3.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202206-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202206-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202206-citibike-tripdata_3.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202206-citibike-tripdata_4.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202207-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202207-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202207-citibike-tripdata_3.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202207-citibike-tripdata_4.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202208-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202208-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202208-citibike-tripdata_3.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202208-citibike-tripdata_4.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202209-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202209-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202209-citibike-tripdata_3.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202209-citibike-tripdata_4.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202210-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202210-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202210-citibike-tripdata_3.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202211-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202211-citibike-tripdata_2.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202211-citibike-tripdata_3.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202212-citibike-tripdata_1.csv',
#  'C:\\Users\\HP\\Citi_Bike_Dashboard\\02 Data\\Original Data\\202212-citibike-tripdata_2.csv']

# %%
#  Read and concatenate all CSV files from the 'filepaths' list
df = pd.concat(
    (pd.read_csv(f, low_memory=False) for f in filepaths),  # Read each file and create a generator expression
    ignore_index=True  # Ensures the index is reset after concatenation
)

#  Display the first few rows to verify data was loaded correctly
print(df.head())
# Out:
#             ride_id  rideable_type               started_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name start_station_id  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St          6364.10
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 1      Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2              5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 3              5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 4              5 Ave & E 29 St        6248.06  40.749640 -73.988050
#
#      end_lat    end_lng member_casual
# 0  40.804038 -73.945925        member
# 1  40.688489 -73.991160        member
# 2  40.745168 -73.986831        member
# 3  40.745168 -73.986831        member
# 4  40.745168 -73.986831        member

# %%
df.shape
# Out:
# (29838806, 13)

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name start_station_id  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St          6364.10
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 1      Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2              5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 3              5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 4              5 Ave & E 29 St        6248.06  40.749640 -73.988050
#
#      end_lat    end_lng member_casual
# 0  40.804038 -73.945925        member
# 1  40.688489 -73.991160        member
# 2  40.745168 -73.986831        member
# 3  40.745168 -73.986831        member
# 4  40.745168 -73.986831        member

# %%
df.tail()
# Out:
#                    ride_id  rideable_type               started_at  \
# 29838801  1F223EDAFF420AE3  electric_bike  2022-12-01 20:26:45.847
# 29838802  CFA5C560ACB73B8E   classic_bike  2022-12-26 13:46:34.237
# 29838803  11C8C5E0DB947B07   classic_bike  2022-12-01 05:56:14.903
# 29838804  5B9B083C534A5964   classic_bike  2022-12-02 11:54:15.871
# 29838805  91C286C462F89A50   classic_bike  2022-12-18 13:35:22.574
#
#                          ended_at        start_station_name start_station_id  \
# 29838801  2022-12-01 20:30:46.012         Avenue D & E 3 St          5436.09
# 29838802  2022-12-26 13:52:43.900            43 Ave & 47 St          6209.05
# 29838803  2022-12-01 06:06:10.357         Avenue D & E 3 St          5436.09
# 29838804  2022-12-02 12:01:00.747  Montague St & Clinton St          4677.06
# 29838805  2022-12-18 13:37:27.193  Montague St & Clinton St          4677.06
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 29838801     Stanton St & Chrystie St        5523.02  40.720701 -73.977939
# 29838802               39 Ave & 45 St        6401.03  40.744806 -73.917290
# 29838803      Bleecker St & Crosby St        5679.08  40.720828 -73.977932
# 29838804            Sands St & Jay St        4821.03  40.694271 -73.992327
# 29838805  Cadman Plaza E & Tillary St        4677.01  40.694271 -73.992327
#
#             end_lat    end_lng member_casual
# 29838801  40.722293 -73.991475        member
# 29838802  40.749478 -73.918265        member
# 29838803  40.726156 -73.995102        member
# 29838804  40.700119 -73.986200        member
# 29838805  40.695977 -73.990149        member

# %% [markdown]
# #### Joining Description

# %% [markdown]
# **Merging Multiple CSV Files into a Single DataFrame**
#
# The following code **reads multiple CSV files** from a directory (03 Data > Prepared Data) and combines them into a **single DataFrame** using `pandas.concat()`.
#
# ---
#
# **How It Works**
# 1. **Iterating Through Files:**
#    - The `filepaths` list contains the **file paths** for all CSV files in the target directory.
#    - A **generator expression** efficiently reads each file using `pd.read_csv(f, low_memory=False)`.
#    - The `low_memory=False` will let pandas process the file in chunks and automatically infer the dtypes.
#
# 2. **Concatenating DataFrames:**
#    - `pd.concat()` merges all **individual DataFrames** into one.
#    - The `ignore_index=True` parameter **resets the index**, preventing duplicate indices from different files.
#
# ---
#
# **Why Use This Approach?**
# - **Efficient** – Uses a generator expression to **avoid excessive memory usage** when handling large datasets.
# **Scalable** – Works dynamically for **any number of files** without manual input.
# **Ensures Data Consistency** – The `ignore_index=True` option prevents index conflicts.

# %% [markdown]
# ### 02. Get weather data using NOAA'a API

# %%
# NOAA API Token

Token = 'idHgEPaWvyuIKGEtItiVgJcyNeTOyKhx'  # This token authenticates API requests to NOAA

# %%
# Importing the NOAA data for LaGuardia Airport NY

r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00014732&startdate=2022-01-01&enddate=2022-12-31', headers={'token':Token})

# %%
# Check HTTP status code

print(r.status_code)
# Out:
# 200

# %% [markdown]
# - I returned the HTTP status code to view if the request was processed correctly.
# - A '200' means the request was successful, no action is needed, and the data is available.

# %%
# Convert the API response into JSON format

d = json.loads(r.text)  # Parses the response text (string) into a Python dictionary

# %%
# Extract all items from the API response where the datatype is 'TAVG' (Average Temperature)
# Check if 'results' exists in the API response before extracting TAVG values
if 'results' in d:
    avg_temps = [item for item in d['results'] if item['datatype'] == 'TAVG']
else:
    avg_temps = []  # Assign an empty list if no data is available
    print("Warning: 'results' key not found in API response.")

# %%
# Get only the date field from all average temperature readings

dates_temp = [item['date'] for item in avg_temps]

# %%
# Get the temperature from all average temperature readings

temps = [item['value'] for item in avg_temps]

# %%
temps
# Out:
# [116,
#  114,
#  14,
#  -27,
#  32,
#  49,
#  7,
#  -25,
#  14,
#  16,
#  -54,
#  -19,
#  40,
#  48,
#  -67,
#  -80,
#  39,
#  18,
#  32,
#  51,
#  -60,
#  -59,
#  -7,
#  -2,
#  36,
#  -23,
#  -42,
#  1,
#  -48,
#  -71,
#  -34,
#  -17,
#  23,
#  64,
#  58,
#  -28,
#  -48,
#  5,
#  41,
#  28,
#  63,
#  86,
#  118,
#  28,
#  -43,
#  -47,
#  16,
#  116,
#  99,
#  1,
#  -26,
#  41,
#  56,
#  144,
#  11,
#  8,
#  -11,
#  24,
#  8,
#  26,
#  77,
#  56,
#  -19,
#  31,
#  96,
#  182,
#  87,
#  32,
#  40,
#  72,
#  51,
#  -23,
#  53,
#  116,
#  136,
#  82,
#  139,
#  131,
#  143,
#  104,
#  107,
#  72,
#  57,
#  96,
#  104,
#  59,
#  -15,
#  -12,
#  26,
#  99,
#  131,
#  72,
#  70,
#  76,
#  97,
#  86,
#  91,
#  128,
#  114,
#  86,
#  88,
#  134,
#  154,
#  163,
#  157,
#  157,
#  83,
#  79,
#  76,
#  94,
#  106,
#  146,
#  133,
#  128,
#  104,
#  115,
#  116,
#  82,
#  104,
#  129,
#  136,
#  121,
#  124,
#  120,
#  172,
#  148,
#  100,
#  104,
#  135,
#  154,
#  161,
#  171,
#  160,
#  179,
#  188,
#  204,
#  197,
#  178,
#  155,
#  154,
#  212,
#  278,
#  210,
#  174,
#  162,
#  164,
#  202,
#  204,
#  207,
#  233,
#  283,
#  178,
#  203,
#  195,
#  219,
#  200,
#  222,
#  218,
#  237,
#  244,
#  218,
#  218,
#  205,
#  242,
#  239,
#  233,
#  203,
#  252,
#  217,
#  173,
#  205,
#  221,
#  191,
#  192,
#  219,
#  258,
#  270,
#  243,
#  224,
#  239,
#  254,
#  281,
#  287,
#  269,
#  256,
#  259,
#  260,
#  242,
#  235,
#  247,
#  234,
#  240,
#  258,
#  289,
#  266,
#  261,
#  243,
#  257,
#  262,
#  282,
#  313,
#  298,
#  309,
#  303,
#  311,
#  298,
#  259,
#  255,
#  267,
#  282,
#  267,
#  263,
#  231,
#  264,
#  276,
#  291,
#  293,
#  296,
#  296,
#  303,
#  313,
#  272,
#  266,
#  256,
#  231,
#  240,
#  243,
#  236,
#  236,
#  241,
#  263,
#  279,
#  253,
#  245,
#  259,
#  269,
#  281,
#  274,
#  278,
#  246,
#  260,
#  268,
#  256,
#  259,
#  217,
#  228,
#  253,
#  258,
#  233,
#  208,
#  218,
#  219,
#  236,
#  232,
#  224,
#  247,
#  229,
#  218,
#  196,
#  208,
#  234,
#  256,
#  232,
#  220,
#  218,
#  151,
#  145,
#  192,
#  194,
#  197,
#  172,
#  166,
#  145,
#  148,
#  152,
#  115,
#  103,
#  138,
#  176,
#  203,
#  139,
#  123,
#  158,
#  170,
#  179,
#  187,
#  157,
#  162,
#  161,
#  166,
#  126,
#  100,
#  111,
#  134,
#  144,
#  147,
#  141,
#  169,
#  183,
#  169,
#  113,
#  108,
#  125,
#  144,
#  169,
#  176,
#  157,
#  152,
#  194,
#  198,
#  213,
#  132,
#  87,
#  126,
#  164,
#  197,
#  129,
#  63,
#  49,
#  73,
#  57,
#  45,
#  28,
#  27,
#  11,
#  66,
#  94,
#  81,
#  100,
#  93,
#  107,
#  122,
#  54,
#  84,
#  57,
#  34,
#  106,
#  70,
#  54,
#  93,
#  138,
#  116,
#  53,
#  22,
#  34,
#  16,
#  3,
#  17,
#  27,
#  62,
#  50,
#  31,
#  17,
#  19,
#  10,
#  38,
#  75,
#  -117,
#  -69,
#  -47,
#  -7,
#  34,
#  64,
#  93,
#  82]

# %%
# Create an empty DataFrame to store the results

df_temp = pd.DataFrame()

# %% [markdown]
# - The code above is creating an empty pandas DataFrame `(df_temps)`.
# - This will prepare a structure to store the extracted temperature data from the NOAA API.

# %%
# Convert date strings to datetime format (removing time component)
df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]

# Convert temperature values from tenths of Celsius to actual Celsius
df_temp['avgTemp'] = [float(v) / 10.0 for v in temps]

# %%
df_temp.tail()
# Out:
#           date  avgTemp
# 360 2022-12-27     -0.7
# 361 2022-12-28      3.4
# 362 2022-12-29      6.4
# 363 2022-12-30      9.3
# 364 2022-12-31      8.2

# %%
df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# Convert the 'started_at' column from string format to a datetime object

df['started_at'] = pd.to_datetime(df['started_at'])

# %%
# Convert the 'started_at' column to a datetime object and extract only the date part

df['date'] = pd.to_datetime(df['started_at'], format='%Y-%m-%d').dt.date

# %%
# Convert the 'date' column from string format to a proper datetime object

df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# ### 03. Merging `df_temp` to `df`

# %%
# Merge the 'df' DataFrame with 'df_temp' on the 'date' column using a left join
df_merged = df.merge(
    df_temp,      # The DataFrame to merge with
    how='left',   # Left join: keeps all rows from 'df', adds matching rows from 'df_temp'
    on='date',    # Common column to merge on
    indicator=True  # Adds a column "_merge" indicating the source of each row
)

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type              started_at  \
# 0  BFD29218AB271154  electric_bike 2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike 2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike 2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike 2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike 2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name start_station_id  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St          6364.10
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# 1      Boerum Pl\t& Pacific St        4488.09  40.673746 -73.985649
# 2              5 Ave & E 29 St        6248.06  40.761227 -73.960940
# 3              5 Ave & E 29 St        6248.06  40.783964 -73.947167
# 4              5 Ave & E 29 St        6248.06  40.749640 -73.988050
#
#      end_lat    end_lng member_casual       date  avgTemp _merge
# 0  40.804038 -73.945925        member 2022-01-21     -6.0   both
# 1  40.688489 -73.991160        member 2022-01-10      1.6   both
# 2  40.745168 -73.986831        member 2022-01-26     -2.3   both
# 3  40.745168 -73.986831        member 2022-01-03      1.4   both
# 4  40.745168 -73.986831        member 2022-01-22     -5.9   both

# %%
# Verifying if merge was successful

df_merged['_merge'].value_counts(dropna = False)
# Out:
# _merge
# both          29838166
# left_only          640
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### Data cleaning of the missing values

# %%
# Identifying the missing dates

missing_dates = df_merged[df_merged['_merge'] == 'left_only']['date'].unique()
print("Missing Dates:", missing_dates)
# Out:
# Missing Dates: <DatetimeArray>
# ['2021-12-31 00:00:00', '2021-12-11 00:00:00', '2021-12-29 00:00:00',
#  '2021-09-13 00:00:00', '2021-12-23 00:00:00', '2021-12-30 00:00:00',
#  '2021-11-16 00:00:00', '2021-11-13 00:00:00', '2021-12-26 00:00:00',
#  '2021-12-12 00:00:00', '2021-11-07 00:00:00', '2021-07-22 00:00:00',
#  '2021-12-04 00:00:00', '2021-12-06 00:00:00', '2021-11-17 00:00:00',
#  '2021-11-09 00:00:00', '2021-12-14 00:00:00', '2021-12-28 00:00:00',
#  '2021-12-19 00:00:00', '2021-12-08 00:00:00', '2021-08-16 00:00:00',
#  '2021-03-14 00:00:00', '2021-11-22 00:00:00', '2021-04-30 00:00:00',
#  '2021-12-02 00:00:00', '2021-09-05 00:00:00', '2021-11-21 00:00:00',
#  '2021-01-30 00:00:00', '2021-06-04 00:00:00', '2021-03-11 00:00:00',
#  '2021-11-18 00:00:00', '2021-02-15 00:00:00', '2021-07-10 00:00:00',
#  '2021-03-31 00:00:00', '2021-07-19 00:00:00', '2021-10-27 00:00:00',
#  '2021-07-16 00:00:00']
# Length: 37, dtype: datetime64[ns]

# %%
# Sort values by date to ensure proper forward filling

df_merged = df_merged.sort_values(by='started_at')

# %%
df_merged.head(50)
# Out:
#                    ride_id  rideable_type              started_at  \
# 7012723   34BD74D84D320CF5  electric_bike 2021-01-30 17:30:45.544
# 16758689  FA436228F4CD7647   classic_bike 2021-02-15 14:11:20.946
# 10829245  8FC77EAE2C0561E4   classic_bike 2021-03-11 22:08:54.461
# 2167335   BF45D1E037463AA8   classic_bike 2021-03-14 18:17:59.923
# 21775695  763D82F8CFA1D9D1   classic_bike 2021-03-31 15:35:20.070
# 2278343   8AFBCFEE21703C2D   classic_bike 2021-04-30 16:56:21.003
# 8617003   E5D3C2D7DE2CD01B   classic_bike 2021-06-04 18:52:01.269
# 19595134  BA13AC6CD2C65E88   classic_bike 2021-07-10 14:53:21.751
# 29395359  90E27C47E17E0F9B   classic_bike 2021-07-16 17:50:59.271
# 27158219  55DE96B9AF7BFDF6   classic_bike 2021-07-19 14:41:06.067
# 591634    2F298092D779509A   classic_bike 2021-07-22 11:49:56.126
# 1895593   2FB77BBBD3113E76   classic_bike 2021-08-16 04:11:29.500
# 26999657  799622522BCC91B3   classic_bike 2021-09-05 17:52:23.693
# 2268856                           Willis Ave & E 137 St          7726.02
# 2796038                     E 58 St & 1 Ave (NE Corner)          6682.03
# 725042                                  6 Ave & W 33 St          6364.07
# 692855                           University Pl & E 8 St          5755.14
# 828239                                 5 Ave & E 103 St          7511.19
# 1887411                     Lawrence St & Willoughby St          4596.09
# 823704                     Lafayette Ave & Ft Greene Pl          4470.09
# 84169                      Lafayette Ave & Ft Greene Pl          4470.09
# 5497072                    Lafayette Ave & Ft Greene Pl          4470.09
# 2642237                 Lafayette Ave & Hunts Point Ave          7883.06
# 573941                               Broadway & W 29 St          6289.06
# 841772                             Sharon St & Olive St          5323.05
# 1099488                               Kent Ave & N 7 St          5489.03
# 148441                          Central Ave & Himrod St          4713.01
# 840618                             Market St & Henry St          5270.09
# 825491                                 W 52 St & 11 Ave          6926.01
# 546228                                 W 52 St & 11 Ave          6926.01
# 842930                                  Southpoint Park          6566.01
# 594744                                    57 St & 4 Ave          3093.07
# 316975                      Central Park West & W 68 St          7079.06
# 908850                               W 42 St & Dyer Ave          6644.07
# 134850                          Dwight St & Van Dyke St          3981.10
# 834170                               Broadway & W 37 St          6441.02
# 838541                                 10 Ave & W 14 St          6157.04
#
#                                            end_station_name end_station_id  \
# 7012723                  Frederick Douglass Blvd & W 112 St        7631.23
# 16758689                             Union Ave & Jackson St        5300.06
# 10829245                           Flatbush Ave & Ocean Ave        3704.04
# 2167335                          S Portland Ave & Hanson Pl        4354.05
# 21775695                          DeKalb Ave & Franklin Ave        4528.01
# 2278343                               Lorimer St & Broadway        4965.01
# 8617003                              Melrose Ave & E 150 St        7879.01
# 19595134                              Popham Ave & W 174 St        8348.02
# 29395359                               Morgan Loading Docks         SYS038
# 27158219                                   E 102 St & 1 Ave        7407.13
# 591634                                 Pier 40 Dock Station         SYS035
# 1895593                            Edgecombe Ave & W 150 St        8049.05
# 26999657                               Pier 40 Dock Station         SYS035
# 4150925                                  Avenue D & E 12 St        5575.08
# 141753    58 St & 2 Ave - Brooklyn Army Terminal Vaccina...        3138.09
# 28515550                            Ashland Pl & Dekalb Ave        4513.09
# 588513                                 Brook Ave & E 138 St        7707.08
# 834778                                                  NaN            NaN
# 360823                                 Fulton St & Pearl St        5024.09
# 7354927                             Townsend Ave & E 175 St        8323.05
# 9964851                            Fairview Ave & Linden St        5066.03
# 243440                           E Tremont Ave & Jerome Ave        8403.02
# 834230                                                  NaN            NaN
# 835746                                                  NaN            NaN
# 10999940                         E Fordham Rd & Webster Ave        8582.09
# 5382672                             Wyckoff Ave & Gates Ave        4847.03
# 2268856                                Pier 40 Dock Station         SYS035
# 2796038                                 Newtown Ave & 23 St        7026.08
# 725042                                  Broadway\t& W 48 St        6708.04
# 692855                                 Ditmars Blvd & 43 St        7039.03
# 828239                                                  NaN            NaN
# 1887411                          Willoughby St & Ashland Pl        4587.02
# 823704                                                  NaN            NaN
# 84169                           Willoughby Ave & Myrtle Ave        4759.02
# 5497072                                Pier 40 Dock Station         SYS035
# 2642237                                     E 58 St & 3 Ave        6762.02
# 573941                                       E 1 St & 1 Ave        5593.01
# 841772                                                  NaN            NaN
# 5497072   40.687002 -73.976650  40.728660 -74.011980        casual 2021-12-11
# 2642237   40.816567 -73.888161  40.760958 -73.967245        casual 2021-12-12
# 573941    40.746201 -73.988557  40.723356 -73.988650        casual 2021-12-12
# 841772    40.715353 -73.938560        NaN        NaN        casual 2021-12-14
# 1099488   40.720368 -73.961651  40.685068 -73.977908        casual 2021-12-19
# 148441    40.696760 -73.923020  40.691220 -73.916930        casual 2021-12-23
# 840618    40.713107 -73.994464        NaN        NaN        casual 2021-12-26
# 825491    40.767272 -73.993929        NaN        NaN        casual 2021-12-26
# 546228    40.767272 -73.993929  40.761712 -73.986551        casual 2021-12-26
# 842930    40.753702 -73.958652        NaN        NaN        casual 2021-12-28
# 594744    40.642622 -74.016866  40.728660 -74.011980        casual 2021-12-29
# 316975    40.773407 -73.977825  40.725029 -73.990697        casual 2021-12-29
# 908850    40.758985 -73.993800  40.825322 -73.887729        casual 2021-12-29
# 134850    40.673636 -74.011956  40.673636 -74.011956        casual 2021-12-29
# 834170    40.751726 -73.987535        NaN        NaN        casual 2021-12-30
# 838541    40.741982 -74.008316        NaN        NaN        casual 2021-12-30
#
#           avgTemp     _merge
# 7012723       NaN  left_only
# 16758689      NaN  left_only
# 10829245      NaN  left_only
# 2167335       NaN  left_only
# 21775695      NaN  left_only
# 2278343       NaN  left_only
# 8617003       NaN  left_only
# 19595134      NaN  left_only
# 29395359      NaN  left_only
# 27158219      NaN  left_only
# 591634        NaN  left_only
# 1895593       NaN  left_only
# 26999657      NaN  left_only
# 4150925       NaN  left_only
# 141753        NaN  left_only
# 28515550      NaN  left_only
# 588513        NaN  left_only
# 834778        NaN  left_only
# 360823        NaN  left_only
# 7354927       NaN  left_only
# 9964851       NaN  left_only
# 243440        NaN  left_only
# 834230        NaN  left_only
# 835746        NaN  left_only
# 10999940      NaN  left_only
# 5382672       NaN  left_only
# 2268856       NaN  left_only
# 2796038       NaN  left_only
# 725042        NaN  left_only
# 692855        NaN  left_only
# 828239        NaN  left_only
# 1887411       NaN  left_only
# 823704        NaN  left_only
# 84169         NaN  left_only
# 5497072       NaN  left_only
# 2642237       NaN  left_only
# 573941        NaN  left_only
# 841772        NaN  left_only
# 1099488       NaN  left_only
# 148441        NaN  left_only
# 840618        NaN  left_only
# 825491        NaN  left_only
# 546228        NaN  left_only
# 842930        NaN  left_only
# 594744        NaN  left_only
# 316975        NaN  left_only
# 908850        NaN  left_only
# 134850        NaN  left_only
# 834170        NaN  left_only
# 838541        NaN  left_only

# %% [markdown]
# After some investigating, it appears that the missing values come from rides that began in 2021 and ended in 2022. Therefore, tying an average daily temperature to that record would not be possible since it is spanning more than one day.
#
# I have decided not to alter the dataset yet in case some data cleaning will be performed later in the exercises. However, I have added in a code below to exclude trips that started in 2021 in case the code is needed later on.

# %%
# Keep only trips that started in 2022
# df_merged = df_merged[df_merged['date'].dt.year == 2022]

# Reset index after filtering
# df_merged.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### 04. Exporting `df_merged` as a CSV file

# %%
# exporting 'df_merged' as a CSV

df_merged.to_csv('newyork_data.csv')

# %%
df_merged.shape
# Out:
# (29838806, 16)
